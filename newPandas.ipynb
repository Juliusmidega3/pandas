# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style

# %%
style.use('fivethirtyeight')

# %%
df = pd.read_csv('Data/from_power_bi.csv')

# %%
df
# Out:
#       Product  Sum of  Sales                   Country  Sum of Discounts  \
# 0    Amarilla       38021.40                    Canada           4224.60
# 1    Amarilla      183540.00                    Canada           9660.00
# 2    Amarilla     1160712.00                    Canada          36388.00
# 3    Amarilla      705600.00                    Canada          78400.00
# 4    Amarilla      180416.25                    Canada          26958.75
# ..        ...            ...                       ...               ...
# 349       VTT        9837.17  United States of America           1215.83
# 350       VTT       18421.20  United States of America           3250.80
# 351       VTT      286605.00  United States of America          37070.00
# 352       VTT     1204444.30  United States of America         154490.70
# 353       VTT      626955.00  United States of America          55295.00
#
#      Sum of Gross Sales  Sum of Sale Price Month Name  Sum of Profit
# ...

# %%
country = df
country
# Out:
#       Product  Sum of  Sales                   Country  Sum of Discounts  \
# 0    Amarilla       38021.40                    Canada           4224.60
# 1    Amarilla      183540.00                    Canada           9660.00
# 2    Amarilla     1160712.00                    Canada          36388.00
# 3    Amarilla      705600.00                    Canada          78400.00
# 4    Amarilla      180416.25                    Canada          26958.75
# ..        ...            ...                       ...               ...
# 349       VTT        9837.17  United States of America           1215.83
# 350       VTT       18421.20  United States of America           3250.80
# 351       VTT      286605.00  United States of America          37070.00
# 352       VTT     1204444.30  United States of America         154490.70
# 353       VTT      626955.00  United States of America          55295.00
#
#      Sum of Gross Sales  Sum of Sale Price Month Name  Sum of Profit
# ...

# %%
df = country.head(9)
df
# Out:
#     Product  Sum of  Sales Country  Sum of Discounts  Sum of Gross Sales  \
# 0  Amarilla      38021.400  Canada          4224.600             42246.0
# 1  Amarilla     183540.000  Canada          9660.000            193200.0
# 2  Amarilla    1160712.000  Canada         36388.000           1197100.0
# 3  Amarilla     705600.000  Canada         78400.000            784000.0
# 4  Amarilla     180416.250  Canada         26958.750            207375.0
# 5  Amarilla      22256.325  Canada          2201.175             24457.5
# 6  Amarilla      20416.050  Canada          1688.950             22105.0
# 7  Amarilla     229104.000  Canada         37296.000            266400.0
# 8  Amarilla     191231.250  Canada         14393.750            205625.0
#
#    Sum of Sale Price Month Name  Sum of Profit
# 0                 12      April      27459.900
# 1                350     August      40020.000
# 2                650   December     219432.000
# 3                350   February     123200.000
# ...

# %%
country.tail(20)
# Out:
#     Product  Sum of  Sales                   Country  Sum of Discounts  \
# 334     VTT       61632.50                    Mexico           7617.50
# 335     VTT        8653.50                    Mexico            961.50
# 336     VTT       90951.84                    Mexico           2284.16
# 337     VTT       17476.06                    Mexico           2844.94
# 338     VTT       38362.50                    Mexico           4262.50
# 339     VTT      120871.15                    Mexico          11213.85
# 340     VTT      670461.95                    Mexico           8221.05
# 341     VTT      127373.40                    Mexico          14286.60
# 342     VTT      430452.75  United States of America          42572.25
# 343     VTT     1539783.00  United States of America         204967.00
# 344     VTT      368633.50  United States of America          24116.50
# 345     VTT      827604.00  United States of America          25596.00
# ...

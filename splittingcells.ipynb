# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
wena = pd.DataFrame({
    'Staff_Name': ['Nancy Mboku','Kelvin Amboso', 'Alex Vikiru','Christine Nyatika', 'Jullius Midega', 'MaryAnn Atieno', 'Margaret Anzetze', 'Mirriam Mikole', 'Scholarstica Atieno','Felix Etsabo Adala' ],
    'Gender': ['Female', 'Male','Male', 'Female','Male', 'Female', 'Female', 'Female', 'Female', 'Male'],
    'Designation': ['Head Teacher', 'Deputy Head Teacher', 'Seniour Teacher', 'Welfare Teacher', 'Clubs Games and Sports', 'Clubs Games and Sports', 'Guiding and counselling', 'Guiding and counselling', 'Welfare', 'Cook'],
    'Year of employement':[
        np.nan,
        '2013',
        '2018',
        '2021',
        '2024',
        '2024',
        '2024',
        '2024',
        '2024',
        '2019'
    ],
    'Salary':[
        np.nan,
        15000,
        10000,
        7000,
        7000,
        7000,
        7000,
        7000,
        7000,
        5000,
    ],
    'Home':['Muzolyo', 'Vusetwa', 'Ingidi', 'Visiru', 'Lusuka', 'Iduku','Mukuli','Mbihi','Kitulu', 'Ebubai'],
    'Ethnicity': [
        'Maragoli',
        'Maragoli',
        'Maragoli',
        'Kisii',
        'Maragoli',
        'Luo',
        'Bukusu',
        'Bunyore',
        'Luo',
        'Bunyore'
    ],
    'Roles':[
        'Headtecher',
        'Class Teacher grade 6',
        'Class Teacher grade 5',
        'Class Teacher grade 2',
        'Class Teacher grade 4',
        'Class Teacher grade 3',
        'Class Teacher grade 1',
        'Class Teacher pp1',
        'Class Teacher pp2',
        np.nan
    ]
})
wena
# Out:
#             Staff_Name  Gender              Designation Year of employement  \
# 0          Nancy Mboku  Female             Head Teacher                 NaN
# 1        Kelvin Amboso    Male      Deputy Head Teacher                2013
# 2          Alex Vikiru    Male          Seniour Teacher                2018
# 3    Christine Nyatika  Female          Welfare Teacher                2021
# 4       Jullius Midega    Male   Clubs Games and Sports                2024
# 5       MaryAnn Atieno  Female   Clubs Games and Sports                2024
# 6     Margaret Anzetze  Female  Guiding and counselling                2024
# 7       Mirriam Mikole  Female  Guiding and counselling                2024
# 8  Scholarstica Atieno  Female                  Welfare                2024
# 9   Felix Etsabo Adala    Male                     Cook                2019
#
#     Salary     Home Ethnicity                  Roles
# 0      NaN  Muzolyo  Maragoli             Headtecher
# ...

# %%
wena.describe()
# Out:
#              Salary
# count      9.000000
# mean    8000.000000
# std     2915.475947
# min     5000.000000
# 25%     7000.000000
# 50%     7000.000000
# 75%     7000.000000
# max    15000.000000

# %%
wena.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Staff_Name           10 non-null     object
#  1   Gender               10 non-null     object
#  2   Designation          10 non-null     object
#  3   Year of employement  9 non-null      object
#  4   Salary               9 non-null      float64
#  5   Home                 10 non-null     object
#  6   Ethnicity            10 non-null     object
#  7   Roles                9 non-null      object
# dtypes: float64(1), object(7)
# memory usage: 772.0+ bytes

# %%
wena.dropna() #drops values with no number values
# Out:
#             Staff_Name  Gender              Designation Year of employement  \
# 1        Kelvin Amboso    Male      Deputy Head Teacher                2013
# 2          Alex Vikiru    Male          Seniour Teacher                2018
# 3    Christine Nyatika  Female          Welfare Teacher                2021
# 4       Jullius Midega    Male   Clubs Games and Sports                2024
# 5       MaryAnn Atieno  Female   Clubs Games and Sports                2024
# 6     Margaret Anzetze  Female  Guiding and counselling                2024
# 7       Mirriam Mikole  Female  Guiding and counselling                2024
# 8  Scholarstica Atieno  Female                  Welfare                2024
#
#   Salary     Home Ethnicity                  Roles
# 1  15000  Vusetwa  Maragoli  Class Teacher grade 6
# 2  10000   Ingidi  Maragoli  Class Teacher grade 5
# 3   7000   Visiru     Kisii  Class Teacher grade 2
# 4   7000   Lusuka  Maragoli  Class Teacher grade 4
# ...

# %%
wena.isnull() #returns the columns with no number in on the columns
# Out:
#    Staff_Name  Gender  Designation  Year of employement  Salary   Home  \
# 0       False   False        False                 True    True  False
# 1       False   False        False                False   False  False
# 2       False   False        False                False   False  False
# 3       False   False        False                False   False  False
# 4       False   False        False                False   False  False
# 5       False   False        False                False   False  False
# 6       False   False        False                False   False  False
# 7       False   False        False                False   False  False
# 8       False   False        False                False   False  False
# 9       False   False        False                False   False  False
#
#    Ethnicity  Roles
# 0      False  False
# 1      False  False
# 2      False  False
# 3      False  False
# 4      False  False
# 5      False  False
# 6      False  False
# ...

# %%
wena.isnull().count()
# Out:
# Staff_Name             10
# Gender                 10
# Designation            10
# Year of employement    10
# Salary                 10
# Home                   10
# Ethnicity              10
# Roles                  10
# dtype: int64

# %%
wena.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Staff_Name           10 non-null     object
#  1   Gender               10 non-null     object
#  2   Designation          10 non-null     object
#  3   Year of employement  9 non-null      object
#  4   Salary               9 non-null      object
#  5   Home                 10 non-null     object
#  6   Ethnicity            10 non-null     object
#  7   Roles                9 non-null      object
# dtypes: object(8)
# memory usage: 772.0+ bytes

# %%
wena.dropna(axis=1)
# Out:
#             Staff_Name  Gender              Designation     Home Ethnicity
# 0          Nancy Mboku  Female             Head Teacher  Muzolyo  Maragoli
# 1        Kelvin Amboso    Male      Deputy Head Teacher  Vusetwa  Maragoli
# 2          Alex Vikiru    Male          Seniour Teacher   Ingidi  Maragoli
# 3    Christine Nyatika  Female          Welfare Teacher   Visiru     Kisii
# 4       Jullius Midega    Male   Clubs Games and Sports   Lusuka  Maragoli
# 5       MaryAnn Atieno  Female   Clubs Games and Sports    Iduku       Luo
# 6     Margaret Anzetze  Female  Guiding and counselling   Mukuli    Bukusu
# 7       Mirriam Mikole  Female  Guiding and counselling    Mbihi   Bunyore
# 8  Scholarstica Atieno  Female                  Welfare   Kitulu       Luo
# 9   Felix Etsabo Adala    Male                     Cook   Ebubai   Bunyore

# %%
wena.fillna(method='ffill')
# Out:
# C:\Users\Julio Lito\AppData\Local\Temp\ipykernel_7748\3602384017.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wena.fillna(method='ffill')
#             Staff_Name  Gender              Designation Year of employement  \
# 0          Nancy Mboku  Female             Head Teacher                 NaN
# 1        Kelvin Amboso    Male      Deputy Head Teacher                2013
# 2          Alex Vikiru    Male          Seniour Teacher                2018
# 3    Christine Nyatika  Female          Welfare Teacher                2021
# 4       Jullius Midega    Male   Clubs Games and Sports                2024
# 5       MaryAnn Atieno  Female   Clubs Games and Sports                2024
# 6     Margaret Anzetze  Female  Guiding and counselling                2024
# 7       Mirriam Mikole  Female  Guiding and counselling                2024
# ...

# %%
wena =wena.fillna({
    'Salary': 20000,
    'Year of employement': 2010,
    'Roles': 'Cook'
})

# %%
wena
# Out:
#             Staff_Name  Gender              Designation Year of employement  \
# 0          Nancy Mboku  Female             Head Teacher                 NaN
# 1        Kelvin Amboso    Male      Deputy Head Teacher                2013
# 2          Alex Vikiru    Male          Seniour Teacher                2018
# 3    Christine Nyatika  Female          Welfare Teacher                2021
# 4       Jullius Midega    Male   Clubs Games and Sports                2024
# 5       MaryAnn Atieno  Female   Clubs Games and Sports                2024
# 6     Margaret Anzetze  Female  Guiding and counselling                2024
# 7       Mirriam Mikole  Female  Guiding and counselling                2024
# 8  Scholarstica Atieno  Female                  Welfare                2024
# 9   Felix Etsabo Adala    Male                     Cook                2019
#
#   Salary     Home Ethnicity                  Roles
# 0    NaN  Muzolyo  Maragoli             Headtecher
# ...

# %%
wena
# Out:
#             Staff_Name  Gender              Designation Year of employement  \
# 0          Nancy Mboku  Female             Head Teacher                2010
# 1        Kelvin Amboso    Male      Deputy Head Teacher                2013
# 2          Alex Vikiru    Male          Seniour Teacher                2018
# 3    Christine Nyatika  Female          Welfare Teacher                2021
# 4       Jullius Midega    Male   Clubs Games and Sports                2024
# 5       MaryAnn Atieno  Female   Clubs Games and Sports                2024
# 6     Margaret Anzetze  Female  Guiding and counselling                2024
# 7       Mirriam Mikole  Female  Guiding and counselling                2024
# 8  Scholarstica Atieno  Female                  Welfare                2024
# 9   Felix Etsabo Adala    Male                     Cook                2019
#
#     Salary     Home Ethnicity                  Roles
# 0  20000.0  Muzolyo  Maragoli             Headtecher
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(wena.index, wena['Salary'])

# %% [markdown]
# SPLITTING CELLS

# %%
df = pd.DataFrame({
    'Data': [
    '1987_M_US_3',
    '1990_M_UK_1',
    '1992_F_US_2',
    '1970_M_IT_1',
    '1985_F_IT_2'
]
})
df
# Out:
#           Data
# 0  1987_M_US_3
# 1  1990_M_UK_1
# 2  1992_F_US_2
# 3  1970_M_IT_1
# 4  1985_F_IT_2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Data    5 non-null      object
# dtypes: object(1)
# memory usage: 172.0+ bytes

# %%
df['Data'].str.split('_')
# Out:
# 0    [1987, M, US, 3]
# 1    [1990, M, UK, 1]
# 2    [1992, F, US, 2]
# 3    [1970, M, IT, 1]
# 4    [1985, F, IT, 2]
# Name: Data, dtype: object

# %%
df['Data'].str.split('_', expand=True)
# Out:
#       0  1   2  3
# 0  1987  M  US  3
# 1  1990  M  UK  1
# 2  1992  F  US  2
# 3  1970  M  IT  1
# 4  1985  F  IT  2

# %%
df = df['Data'].str.split('_', expand=True)

# %%
df.columns = ['Year', 'Sex','Country','Number of Children']
df
# Out:
#    Year Sex Country Number of Children
# 0  1987   M      US                  3
# 1  1990   M      UK                  1
# 2  1992   F      US                  2
# 3  1970   M      IT                  1
# 4  1985   F      IT                  2
